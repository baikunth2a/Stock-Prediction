# %% [markdown]
# ### Dependencies

# %%
#!pip install Keras
#!pip install tensorflow
#!pip install attention

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wavlet import WT,snr

# %% [markdown]
# ### Read data and set date column as index

# %%
df= pd.read_excel('dataset/Agricultural_development_bank_limited.xlsx', index_col=1)
df.drop('S.N.', axis=1, inplace=True)
df.index = pd.to_datetime(df.index)

# %%
df.head(3)
# Out:
#             Open  High  Low  Close  Volume  Turnover
# Date
# 2011-03-20   132   134  131    133    1507    198979
# 2011-03-24   135   136  129    133    3116    415035
# 2011-03-25   133   135  132    135    2560    342820

# %% [markdown]
# ### Perform wavlet transform to all data columns to reduce noise

# %%
X=[]
sn=0
i=0
for col in df.columns:
    pred = np.sum(WT(df[col], wavefunc='coif4',plot=False), axis=0)
    X.append(pred)
    sn = sn + snr(df[col].to_numpy(),pred)
    i = i+1
d_clean = pd.DataFrame(data={'Open': X[0], 'High': X[1], 'Low':X[2],'Close':X[3],'Volume':X[4],'Turnover':X[5]}, index = df.index)
print(f'Average SNR: {sn/i}')
# Out:
# Average SNR: 19.981927536339054

# %% [markdown]
# ### Added moving average close price as a feature

# %%
d_clean['mov_avg_close'] = df['Close'].rolling(10).mean()
d_clean.dropna(inplace = True)

# %%
d_clean.head(3)
# Out:
#                   Open        High         Low       Close       Volume  \
# Date
# 2011-04-05  127.716439  128.669789  125.045970  127.055026  1978.924817
# 2011-04-06  127.121424  128.068395  124.481392  126.448421  1972.457672
# 2011-04-07  126.569106  127.516451  123.960086  125.892814  1967.739301
#
#                  Turnover  mov_avg_close
# Date
# 2011-04-05  252213.685783          131.2
# 2011-04-06  250207.787532          131.0
# 2011-04-07  248504.842781          130.5

# %% [markdown]
# ### Visualization of denoised data (500 sample data)

# %%
fig, axs = plt.subplots(1,2, figsize = (16,4))
axs[0].plot(df['Close'][:500], 'r-', d_clean['Close'][:500])
axs[0].set_title("Noised Vs denoised data for Close Price column (100 Samples)")
axs[0].legend(['Noised', 'Desnoised'])

axs[1].plot(d_clean[['Open','High','Low','Close']][:500])
axs[1].set_title("Denoised data for all column (100 Samples)")
axs[1].legend(['Open','High','Low','Close'])
plt.show()

# %% [markdown]
# ### Open, high, low and close price history (denoised) and moving average of close price

# %%
plt.figure(figsize = (15, 5))
plt.title('Price History (Since 2018)')
plt.plot(d_clean[['Open','High','Low','Close', 'mov_avg_close']]['2018-01-01':'2021-01-01']);
plt.legend(['Open','High','Low','Close', 'mov_avg_close'])

# %% [markdown]
# ### Taking only relevant features for training and prediction

# %%
data = d_clean.filter(['Close', 'Volume', 'Turnover', 'mov_avg_close']).values

# %% [markdown]
# ### Data normalization (minmax scaling)

# %%
s_data = (data - data.min(axis=0)) / (data.max(axis=0) - data.min(axis=0))

# %% [markdown]
# ### Train test (80-20) sequence split taking 60 past sequences as feature vector

# %%
import math
t_len = math.ceil(len(data) * .8)
train_data = s_data[0:t_len, :]
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, :])
    y_train.append(train_data[i,0])

# %% [markdown]
# ### Training data size

# %%
print(f'Training data X shape: {np.shape(x_train)} \nTraining data Y shape: {np.shape(y_train)}')
# Out:
# Training data X shape: (1711, 60, 4)
# Training data Y shape: (1711,)

# %% [markdown]
# ### Reshape 2D training data into 3D (LSTM takes 3D data as input)

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
# x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (1711, 60, 4)

# %% [markdown]
# ### Preparing LSTM with Attention model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras_self_attention import SeqSelfAttention
from attention import Attention
from keras.utils.vis_utils import plot_model

model = Sequential([
        LSTM(40, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True),
        Attention(),
        Dense(50, activation = 'sigmoid'),
        Dense(1, activation = 'linear')
    ])
plot_model(model, to_file='cmdmodel_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Training the model

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
History = model.fit(x_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 2s 9ms/step - loss: 0.3679
# Epoch 2/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0337
# Epoch 3/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 4/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 5/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.3507e-04
# Epoch 6/100
# 54/54 [==============================] - 0s 8ms/step - loss: 6.6595e-04
# Epoch 7/100
# 54/54 [==============================] - 0s 8ms/step - loss: 4.5140e-04
# Epoch 8/100
# 54/54 [==============================] - 0s 8ms/step - loss: 3.4878e-04
# Epoch 9/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.0027e-04
# Epoch 10/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.5341e-04
# Epoch 11/100
# 54/54 [==============================] - 0s 8ms/step - loss: 3.5548e-04
# Epoch 12/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.3162e-04
# Epoch 13/100
# 54/54 [==============================] - 0s 8ms/step - loss: 2.0614e-04
# Epoch 14/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.7006e-04
# Epoch 15/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.7823e-04
# Epoch 16/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.4463e-04
# Epoch 17/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.7305e-04
# Epoch 18/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.2510e-04
# Epoch 19/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.3271e-04
# Epoch 20/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1288e-04
# Epoch 21/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.2289e-05
# Epoch 22/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.6173e-05
# Epoch 23/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.4822e-05
# Epoch 24/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.0510e-04
# Epoch 25/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.1931e-05
# Epoch 26/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.8651e-05
# Epoch 27/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.9510e-05
# Epoch 28/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.5498e-05
# Epoch 29/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.4363e-05
# Epoch 30/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.5233e-05
# Epoch 31/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.4093e-05
# Epoch 32/100
# 54/54 [==============================] - 1s 10ms/step - loss: 4.8683e-05
# Epoch 33/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.9492e-05
# Epoch 34/100
# 54/54 [==============================] - 1s 10ms/step - loss: 4.3708e-05
# Epoch 35/100
# 54/54 [==============================] - 1s 9ms/step - loss: 3.4587e-05
# Epoch 36/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.6883e-05
# Epoch 37/100
# 54/54 [==============================] - 1s 9ms/step - loss: 3.8800e-05
# Epoch 38/100
# 54/54 [==============================] - 1s 10ms/step - loss: 2.9500e-05
# Epoch 39/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.8922e-05
# Epoch 40/100
# 54/54 [==============================] - 0s 9ms/step - loss: 4.7194e-05
# Epoch 41/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.9985e-05
# Epoch 42/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.5527e-05
# Epoch 43/100
# 54/54 [==============================] - 1s 9ms/step - loss: 3.4870e-05
# Epoch 44/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.0324e-05
# Epoch 45/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.3089e-05
# Epoch 46/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.3639e-05
# Epoch 47/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.0629e-05
# Epoch 48/100
# 54/54 [==============================] - 1s 9ms/step - loss: 2.2030e-05
# Epoch 49/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.7383e-05
# Epoch 50/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.6634e-05
# Epoch 51/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.6596e-05
# Epoch 52/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.4550e-05
# Epoch 53/100
# 54/54 [==============================] - 1s 10ms/step - loss: 1.8175e-05
# Epoch 54/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.2719e-05
# Epoch 55/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1548e-05
# Epoch 56/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.3697e-05
# Epoch 57/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.5066e-05
# Epoch 58/100
# 54/54 [==============================] - 1s 10ms/step - loss: 1.0055e-05
# Epoch 59/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.6026e-05
# Epoch 60/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.0836e-05
# Epoch 61/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.6090e-06
# Epoch 62/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.5066e-05
# Epoch 63/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.6749e-05
# Epoch 64/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.1468e-06
# Epoch 65/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.9655e-06
# Epoch 66/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.9014e-05
# Epoch 67/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.9342e-05
# Epoch 68/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.8973e-05
# Epoch 69/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.8215e-06
# Epoch 70/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.4356e-06
# Epoch 71/100
# 54/54 [==============================] - 0s 9ms/step - loss: 2.1170e-05
# Epoch 72/100
# 54/54 [==============================] - 0s 9ms/step - loss: 9.4567e-06
# Epoch 73/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1231e-05
# Epoch 74/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.0550e-06
# Epoch 75/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.3083e-05
# Epoch 76/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.6702e-06
# Epoch 77/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.6347e-06
# Epoch 78/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.7673e-06
# Epoch 79/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.2393e-06
# Epoch 80/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.0452e-05
# Epoch 81/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1750e-05
# Epoch 82/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.4786e-05
# Epoch 83/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.4368e-05
# Epoch 84/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.4825e-05
# Epoch 85/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.3027e-06
# Epoch 86/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.2569e-05
# Epoch 87/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.5057e-05
# Epoch 88/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.2457e-06
# Epoch 89/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.8226e-06
# Epoch 90/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.6360e-05
# Epoch 91/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.4413e-06
# Epoch 92/100
# 54/54 [==============================] - 0s 9ms/step - loss: 3.2759e-05
# Epoch 93/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.3322e-05
# Epoch 94/100
# 54/54 [==============================] - 0s 9ms/step - loss: 1.1580e-05
# Epoch 95/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.9837e-06
# Epoch 96/100
# 54/54 [==============================] - 1s 10ms/step - loss: 9.6132e-06
# Epoch 97/100
# 54/54 [==============================] - 0s 9ms/step - loss: 5.6090e-06
# Epoch 98/100
# 54/54 [==============================] - 0s 9ms/step - loss: 8.2819e-06
# Epoch 99/100
# 54/54 [==============================] - 0s 9ms/step - loss: 6.3090e-06
# Epoch 100/100
# 54/54 [==============================] - 0s 9ms/step - loss: 7.5989e-06

# %% [markdown]
# ### Training loss graph

# %%
plt.plot(History.history['loss'][:], label='Training loss');
plt.title('Training Loss');

# %% [markdown]
# ### Test data preparation

# %%
test_data = s_data[t_len-60: , :]
x_test = []
y_test = data[t_len: , 0]

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, :])

x_test = np.array(x_test)
#x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape
# Out:
# (442, 60, 4)

# %% [markdown]
# ### Predict for test data

# %%
predictions = model.predict(x_test)

#Inverse scaling for close price
predictions = predictions * (data[:, 0].max() -  data[:, 0].min()) + data[:, 0].min()

# %% [markdown]
# ### RMSE error

# %%
print(np.sqrt(np.mean(predictions - y_test)**2))
# Out:
# 2.4931116268023787

# %% [markdown]
# ### Visualization of training and predicted graph

# %%
### RMSE errorplt.style.use('ggplot')

train = d_clean[:t_len]
valid = d_clean[t_len:]
valid['Predictions'] = predictions
plt.figure(figsize = (18,8))
plt.plot(train['Close']['20140101':])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'])
plt.title('Predicted Graph');
# Out:
# <ipython-input-22-c10d0f2daa1c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %% [markdown]
# ### Close up look of prediction for 2019 to 2020

# %%
plt.figure(figsize = (18,8))
plt.plot(valid[['Close', 'Predictions']]['20190101':'20200101']);
plt.legend(['Validation', 'Predictions'])
plt.title('Prediction for 2019 to 2020');
